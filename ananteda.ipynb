# %%
import pandas as pd
import numpy as  np
import seaborn as sns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
data=pd.read_csv('/content/google.csv')

# %%
data.head()
# Out:
#                Country Retail & recreation Grocery & pharmacy Parks  \
# 0          Afghanistan                -38%               -21%  -13%
# 1               Angola                -61%               -40%  -39%
# 2  Antigua and Barbuda                -46%               -21%  -30%
# 3            Argentina                -86%               -61%  -89%
# 4                Aruba                -88%               -66%  -80%
#
#   Transit stations Workplaces Residential
# 0             -34%       -33%         10%
# 1             -57%       -11%         22%
# 2             -67%       -48%     *\n+17%
# 3             -80%       -57%         27%
# 4             -88%       -72%         20%

# %%
data.tail()
# Out:
#        Country Retail & recreation Grocery & pharmacy Parks Transit stations  \
# 188  Venezuela                -62%               -44%  -57%             -62%
# 189    Vietnam                -52%               -29%  -33%             -49%
# 190      Yemen                 -8%                -1%   -9%              -9%
# 191     Zambia                -21%                -8%   -6%             -24%
# 192   Zimbabwe                 -2%                24%   -4%              -6%
#
#     Workplaces Residential
# 188       -25%         16%
# 189       -20%         16%
# 190        -5%    Baseline
# 191         0%         10%
# 192        14%         13%

# %%
data.shape
# Out:
# (193, 7)

# %%
data.describe()
# Out:
#             Country Retail & recreation Grocery & pharmacy Parks  \
# count           193                 193                193   193
# unique          181                  76                 83    99
# top     Afghanistan                -45%               -25%  -59%
# freq              2                  12                 10     6
#
#        Transit stations Workplaces Residential
# count               193        193         193
# unique               73         69          36
# top                -34%       -38%         13%
# freq                  8          9          17

# %%
data.columns
# Out:
# Index(['Country', 'Retail & recreation', 'Grocery & pharmacy', 'Parks',
#        'Transit stations', 'Workplaces', 'Residential'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Country                181
# Retail & recreation     76
# Grocery & pharmacy      83
# Parks                   99
# Transit stations        73
# Workplaces              69
# Residential             36
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Country                0
# Retail & recreation    0
# Grocery & pharmacy     0
# Parks                  0
# Transit stations       0
# Workplaces             0
# Residential            0
# dtype: int64

# %%
data.dtypes
# Out:
# Country                object
# Retail & recreation    object
# Grocery & pharmacy     object
# Parks                  object
# Transit stations       object
# Workplaces             object
# Residential            object
# dtype: object

# %%
data
# Out:
#                     Country Retail & recreation Grocery & pharmacy   Parks  \
# 0               Afghanistan                -38%               -21%    -13%
# 1                    Angola                -61%               -40%    -39%
# 2       Antigua and Barbuda                -46%               -21%    -30%
# 3                 Argentina                -86%               -61%    -89%
# 4                     Aruba                -88%               -66%    -80%
# 5                 Australia                -45%               -19%    -35%
# 6                   Austria                -87%               -64%    -43%
# 7                   Bahrain                -45%               -22%    -40%
# 8                Bangladesh                -68%               -46%    -26%
# 9                  Barbados                -70%               -47%    -60%
# 10                  Belarus                -14%                 5%     41%
# ...

# %%
data.loc[data['Residential'] == 'Baseline', 'Residential'] = 0

# %%
data = data.drop([2,13,56,112, 102, 78])

# %%
data['Retail & recreation	'] = data['Retail & recreation'].str.split('%').str[0]

# %%
data['Retail & recreation'] = data['Retail & recreation'].str.split('%').str[0]
data['Grocery & pharmacy'] = data['Grocery & pharmacy'].str.split('%').str[0]
data['Parks'] = data['Parks'].str.split('%').str[0]
data['Workplaces'] = data['Workplaces'].str.split('%').str[0]
data['Residential'] = data['Residential'].str.split('%').str[0]
data['Transit stations'] = data['Transit stations'].str.split('%').str[0]

# %%
data['Retail & recreation	'] = pd.to_numeric(data['Retail & recreation'])
data['Retail & recreation'] = pd.to_numeric(data['Retail & recreation'])
data['Grocery & pharmacy'] = pd.to_numeric(data['Grocery & pharmacy'])
data['Parks	'] = pd.to_numeric(data['Parks'])
data['Workplaces'] = pd.to_numeric(data['Workplaces'])
data['Residential'] = pd.to_numeric(data['Residential'])
data['Transit stations'] = pd.to_numeric(data['Transit stations'])

# %%
sns.pairplot(data)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 9 (	) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 9 (	) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
